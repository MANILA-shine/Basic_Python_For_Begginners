# %% [markdown]
# # Python
#
#
# * Created in 1991 by Guido van Rossum
# * It is a versatile programming language that is commonly used for scripting     tasks.
# * Python can function as both a programming and scripting language.
# * Python is classified as an interpreted language.

# %% [markdown]
#  ![cs2.png](attachment:cs2.png)

# %% [markdown]
# * a b to create cell above and below
# * dd double d for deleting
# * z to undo deleted cell

# %% [markdown]
# # Numerical Calculations

# %% [markdown]
# ![SD1.png](attachment:SD1.png)

# %%
2+3
# Out:
# 5

# %%
3>2
# Out:
# True

# %%
5-1
# Out:
# 4

# %%
2<=2
# Out:
# True

# %%
6<8
# Out:
# True

# %%
6<1
# Out:
# False

# %%
6==6  # to compare use '=='
# Out:
# True

# %%
a=7 # To assign a value use '='
a
# Out:
# 7

# %%
a
# Out:
# 7

# %%
6<=6
# Out:
# True

# %%
3*3*3
# Out:
# 27

# %%
2*2*2*2
# Out:
# 16

# %%
3**4
# Out:
# 81

# %%
2**4 # exponential
# Out:
# 16

# %%
6/8
# Out:
# 0.75

# %%
4/2
# Out:
# 2.0

# %%
6/8
# Out:
# 0.75

# %%
6//8 # to avoid decimal value
# Out:
# 0

# %%
29/3
# Out:
# 9.666666666666666

# %%
29//3
# Out:
# 9

# %%
# Modular (%) gives remainder of the value we are dividing

6%3
# Out:
# 0

# %%
12%5
# Out:
# 2

# %%
# UnderScore
#### Traceback (most recent call last)

# %%
3
# Out:
# 3

# %%
_
# Out:
# 3

# %%
4
# Out:
# 4

# %%
_
# Out:
# 4

# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
_
# Out:
# 6

# %% [markdown]
# * # EVEN --->    X%2=0
# *  # ODD  ----> X%2!=0    (NOT EQUAL TO 0)      /       X % 2==1

# %%
2!=1
# Out:
# True

# %%
2!=2 # bcoz 2==2
# Out:
# False

# %%
4%2  # even
# Out:
# 0

# %%
5%2 # odd
# Out:
# 1

# %%
7%2
# Out:
# 1

# %%
10%2
# Out:
# 0

# %%
a=5

# %%
 a=5
     a
# Out:
#   Cell In[43], line 2
#     a
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# * #### Indentation refers to the spaces at the beginning of a code line.
# * #### Where in other programming languages the indentation in code is for readability only, the indentation in Python is very     important.
# * #### Python uses indentation to indicate a block of code.

# %%
a=Hello world
# Out:
#   Cell In[45], line 1
#     a=Hello world
#             ^
# SyntaxError: invalid syntax

# %%
a= 'Hello World'

# %%
          a
    a
# Out:
#   Cell In[34], line 2
#     a
#     ^
# IndentationError: unexpected indent

# %%
  a= 'Hello World'
           a
# Out:
#   Cell In[35], line 2
#     a
#     ^
# IndentationError: unexpected indent

# %%
        a= 'Hello World'
        a
# Out:
# 'Hello World'

# %%
#qwert

# %%
# A text placed within a program to help other users to understand it, which the computer ignores when running the program

# %%
pwd # Path
# Out:
# 'C:\\Users\\manil\\my class'

# %%
3+2
# Out:
# 5

# %%
3 and 2
# Out:
# 2

# %%
3-2
# Out:
# 1

# %%
3 or 2
# Out:
# 3

# %%
2 or 3
# Out:
# 2

# %%
3+2*100
# Out:
# 203

# %%
3+2*100/10
# Out:
# 23.0

# %%
10/5    # gives value in decimal, call it float values too
# Out:
# 2.0

# %%
10//5  #gives value without decimal
# Out:
# 2

# %% [markdown]
#  ### + -- Add
#  ### - Sub
#  ### * Mul
#  ### / Div

# %% [markdown]
# # PEMDAS
#
#
# 1.P-() Paranthesis
# 2.E-** Exponential
# 3.M,D,A,S-Mul div add sub - which ever comes first

# %% [markdown]
# # hello
#
# ## m and y
#
# ### head
# #### sub head
# ##### five
# ###### max 6
# #######  dont work beyond 6

# %% [markdown]
# # Pointers
# * point     # *
#  * pointer2  # space *
#    *  pointer 3 # space space *
#    1.pt
#
#    A. qwe
#
#    a.qwert

# %% [markdown]
# * hi
#  * hello
#    * hey

# %% [markdown]
# * po
#     * point
#         * point
#             * point
#                 * point
#                     * point

# %% [markdown]
# * 0 space
#   * 2 space
#     * 4 space
#       * 6 space
#         * 8 space
#           * 10 space
#             * 12 space
#                 * 16 space
#                     * 20 space

# %% [markdown]
# # Using Text in Cell

# %%
How Variables really work!!
# Out:
#   Cell In[49], line 1
#     How Variables really work!!
#         ^
# SyntaxError: invalid syntax

# %%
'''apple'''
# Out:
# 'apple'

# %%
#"How Variables really work!!"

# %%
"How Variables really work!!" # can add comment
# Out:
# 'How Variables really work!!'

# %%
2
3
4
5    # alwayd take the updated value
# Out:
# 5

# %%
a=4
b=5
c=6
a
b
c
# Out:
# 6

# %% [markdown]
# # Creating variables

# %%
var=100

# %%
var
# Out:
# 100

# %% [markdown]
# #### Not allowed
# * 2=3
# * v a r=3
# * v*a&r=2

# %% [markdown]
# The names you use when creating these labels need to follow a few rules:
#
#     1. Names can not start with a number.
#     2. There can be no spaces in the name, use _ instead.
#     3. Can't use any of these symbols :'",<>/?|\()!@#$%^&*~-+
#     4. It's considered best practice (PEP8) that names are lowercase.
#     5. Avoid using the characters 'l' (lowercase letter el), 'O' (uppercase letter oh),
#        or 'I' (uppercase letter eye) as single character variable names.
#     6. Avoid using words that have special meaning in Python like "list" and "str"

# %%
# not suggested
l=1
O=0
I="Roman"

# %% [markdown]
# # types of values
# * integer  int()  eg 2 3 4
# * float    float() eg 2.3 4.5
# * string   str()   "text", 'text','''text'''
# * boolean  bool()   True False

# %% [markdown]
# ![sd2.png](attachment:sd2.png)

# %%
i=2
f=3.4
s="text"# "a" "abc xyz"#--- all one value
b=True

# %%
type(b)
# Out:
# bool

# %%
1/2
# Out:
# 0.5

# %%
a=2 # INT
type(a)
# Out:
# int

# %%
a=2.4 # FLOAT
type(a)
# Out:
# float

# %%
a="2TEXT" # STR
type(a)
# Out:
# str

# %%
a=True # BOOL
type(a)
# Out:
# bool

# %%
var=10

# %%
var=10
var
# Out:
# 10

# %%
var 2=100
# Out:
#   Cell In[65], line 1
#     var 2=100
#         ^
# SyntaxError: invalid syntax

# %%
var_2=100 # use underscore instead of space

# %%
2=200
# Out:
#   Cell In[67], line 1
#     2=200
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
_=9
_2=200
_2
# Out:
# 200

# %%
2abc=300
# Out:
#   Cell In[69], line 1
#     2abc=300
#     ^
# SyntaxError: invalid decimal literal

# %%
_2abc=300

# %%
abc2=100

# %%
abc2
# Out:
# 100

# %%
a_b8_9c=6

# %%
_2abc + a_b8_9c
# Out:
# 306

# %%
a=2  # Last line in output
a=3
a=4
a
# Out:
# 4

# %%
a=2
print(a)
b=3
print(b)
c=4
c
# Out:
# 2
# 3
# 4

# %%
2 # comment
3
4
5
# Out:
# 5

# %% [markdown]
# # String
#
# * ### The string is defined as a sequence or list of characters
# * ### String is immutable in nature meaning once defined, they cannot be changed.
# * ### str is the type for strings in Python.
# * ### Define strings using quotes (“ or ‘ or “““)

# %% [markdown]
# * ### The string is enclosed in double quotes, if the string contains a single quote and no double quotes, otherwise it is enclosed in single quotes.

# %%
"Hello"
# Out:
# 'Hello'

# %%
"Hello's"
# Out:
# "Hello's"

# %%
"Hello's'
# Out:
#   Cell In[80], line 1
#     "Hello's'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
st = '''This is a multi-line
string that uses triple quotes.'''

# %%
st
# Out:
# 'This is a multi-line\nstring that uses triple quotes.'

# %%
original_string = "Hello, "

# Using repetition to create a new string by repeating the original string
repeated_string = original_string * 3  # Repeat three times
print(repeated_string)
# Out:
# Hello, Hello, Hello,

# %%
# Two strings to concatenate
string1 = "Hello, "
string2 = "World!"

# Concatenating strings using the + operator
concatenated_string = string1 + string2

# Displaying the result
print(concatenated_string)
# Out:
# Hello, World!

# %%
name = "Alice"
greeting = "Hi, " + name + "! Welcome to Python."

print(greeting)
# Out:
# Hi, Alice! Welcome to Python.

# %% [markdown]
# #### The backslash is often used to introduce escape sequences, which represent special characters

# %%
my_string = 'She said, 'Hello!''
print(my_string)
# Out:
#   Cell In[86], line 1
#     my_string = 'She said, 'Hello!''
#                             ^
# SyntaxError: invalid syntax

# %%
my_string = 'She said, \'Hello!\''
print(my_string)
# Out:
# She said, 'Hello!'

# %%
string = "He said, "Python is awesome!""
print(string)
# Out:
#   Cell In[88], line 1
#     string = "He said, "Python is awesome!""
#                         ^
# SyntaxError: invalid syntax

# %%
string = "He said, \"Python is awesome!\""
print(string)
# Out:
# He said, "Python is awesome!"

# %%
multiline_string = "This is a line with a newline character.\nAnd this is the second line."
indented_string = "This line\tcontains a tab character."
print(multiline_string)
print(indented_string)
# Out:
# This is a line with a newline character.
# And this is the second line.
# This line	contains a tab character.

# %%
            # press tab for 3 to 4 times

# %%
single_quoted_sentence = "She said, "Python is incredible!""
# Out:
#   Cell In[92], line 1
#     single_quoted_sentence = "She said, "Python is incredible!""
#                                          ^
# SyntaxError: invalid syntax

# %%
single_quoted_sentence = 'She said, "Python is incredible!"'
print(single_quoted_sentence )
# Out:
# She said, "Python is incredible!"

# %%
double_quoted_sentence = "He exclaimed, 'Learning Python is fun!'"
print(double_quoted_sentence )
# Out:
# He exclaimed, 'Learning Python is fun!'

# %%
triple_quoted_sentence = '''The instructor asked,
"What do you think of triple-quoted strings in Python?"'''
print(triple_quoted_sentence)
# Out:
# The instructor asked,
# "What do you think of triple-quoted strings in Python?"

# %%
double_triple_quoted_sentence = """Triple quotes can also handle
multiline strings, providing a cleaner way to format text."""
print(double_triple_quoted_sentence)
# Out:
# Triple quotes can also handle
# multiline strings, providing a cleaner way to format text.

# %% [markdown]
# # String Operations

# %%
a="qwerty"
 # 0123456 6-1  ,n-1

# %%
# indexing
a[0]
# Out:
# 'q'

# %%
a[2]
# Out:
# 'e'

# %%
a[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 a[6]
#
# IndexError: string index out of range

# %%
a[5]

# %%
a

# %%
a[-1] # -1 to -6 ---- -1=y
# Out:
# 'y'

# %%
a[-4]
# Out:
# 'e'

# %% [markdown]
# # Functions of strings

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
"HELLO".lower()
# Out:
# 'hello'

# %%
"hello hi".title()
# Out:
# 'Hello Hi'

# %%
"hello sam how r u".capitalize()
# Out:
# 'Hello sam how r u'

# %%
"hello sam how r u".endswith("u")
# Out:
# True

# %%
"hello sam how r u".endswith("m")
# Out:
# False

# %%
"hello sam how r u".replace("h","H")
# Out:
# 'Hello sam How r u'

# %%
"hello sam how r u".find("r")
# Out:
# 14

# %%
"hello sam how r u".find("how")
# Out:
# 10

# %%
"hello Sam How r u".swapcase()
# Out:
# 'HELLO sAM hOW R U'

# %%
sentence = "python programming is fun"
# Capitalize the first letter
modified_sentence = sentence.capitalize()
print(modified_sentence)
# Out:
# Python programming is fun

# %%
# Convert to uppercase
modified_sentence_upper = sentence.upper()
print(modified_sentence_upper)
# Out:
# PYTHON PROGRAMMING IS FUN

# %%
# Replace "fun" with "exciting"
modified_sentence_replace = sentence.replace("fun", "exciting")
print(modified_sentence_replace)
# Out:
# python programming is exciting

# %% [markdown]
# ![sd3.png](attachment:sd3.png)

# %% [markdown]
# # SLICING

# %%
a="qwerty"
a
# Out:
# 'qwerty'

# %%
a[:]
# Out:
# 'qwerty'

# %%
a[4]
# Out:
# 't'

# %%
a[:4] # why not t , n-1.... higer-1 index
# Out:
# 'qwer'

# %%
a[:5]
# Out:
# 'qwert'

# %%
a[1:5] # lower is included but higher is not
# Out:
# 'wert'

# %%
a
# Out:
# 'qwerty'

# %%
a[:-1]
# Out:
# 'qwert'

# %%
a[-3:-1]   # a[-1:-3] no becz it read left to right
# Out:
# 'rt'

# %%
a[-4:5]  # code reading from left to right
# Out:
# 'ert'

# %%
a
# Out:
# 'qwerty'

# %%
a[2]
# Out:
# 'e'

# %%
a[-4:2]
# Out:
# ''

# %%
a[-2:2] # not able to read, becz left to right
# Out:
# ''

# %%
string = "Python is powerful"
modified =string[:6] + "awesome"
print(modified)
# Out:
# Pythonawesome

# %% [markdown]
# # Slice with direction

# %%
a
# Out:
# 'qwerty'

# %%
a[::1] # default
# Out:
# 'qwerty'

# %%
a[::-1]
# Out:
# 'ytrewq'

# %%
a[::-2] # step / jump
# Out:
# 'yrw'

# %%
b="abcdefghijklmnopqrstuvwxyz"
b[::-5]
# Out:
# 'zupkfa'

# %%
b[::5]
# Out:
# 'afkpuz'

# %%
b[10:1:1]
# Out:
# ''

# %%
b[1:10:2]
# Out:
# 'bdfhj'

# %%
b[10:1:-1]
# Out:
# 'kjihgfedc'

# %%
b[10:1:-2]
# Out:
# 'kigec'

# %%
b[-1:-10:-2]
# Out:
# 'zxvtr'

# %%
a
# Out:
# 'qwerty'

# %%
a[::-1]
# Out:
# 'ytrewq'

# %%
a[0]="Q" # not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 a[0]="Q" # not allowed
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # Basic print

# %%
"hello"
# Out:
# 'hello'

# %%
h="hello"
h
# Out:
# 'hello'

# %%
q="quaity"
q
# Out:
# 'quaity'

# %%
h
q
# Out:
# 'quaity'

# %%
q
h
# Out:
# 'hello'

# %%
print(h)
print(q)
# Out:
# hello
# quaity

# %%
print("hello")
# Out:
# hello

# %%
name="SAM"
print("hello ",name) # mind comma
# Out:
# hello  SAM

# %% [markdown]
# # Dynamic Typing
#
# #### Python is case sensitive  T not equals to t
# #### Python read code from top to bottom
# #### Python read lines from left to right

# %%
a=2
print(type(a),"Value in a=",a)
a=2.4
print(type(a),"Value in a=",a)
a=True
print(type(a),"Value in a=",a)
a="Hello"
print(type(a),"Value in a=",a)
# Out:
# <class 'int'> Value in a= 2
# <class 'float'> Value in a= 2.4
# <class 'bool'> Value in a= True
# <class 'str'> Value in a= Hello

# %% [markdown]
# # Print Method

# %%
print()

# %%
"hi"
"qwert werqwe qwe qwe er"
"a"
"a","b","c",var
"abc"
# Out:
# 'abc'

# %%
a=100
b="price is ="
print("Product",b,a)
# Out:
# Product price is = 100

# %%
# que
name="Sam"
city="qwert"
"Hello i am", name," and i live in CITY"
# Out:
# ('Hello i am', 'Sam', ' and i live in CITY')

# %%
print("Hello i am", name," and i live in",city)
# Out:
# Hello i am Sam  and i live in qwert

# %%
print("hi)   # SyntaxError
# Out:
#   Cell In[159], line 1
#     print("hi)   # SyntaxError
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # Next Line

# %%
print("hello hi")
print("hello \nhi")
print("----------------")
print("hello \n\n\n\n\n hi")
# Out:
# hello hi
# hello
# hi
# ----------------
# hello
#
#
#
#
#  hi

# %%
print("hello","Hi","!!!")
# Out:
# hello Hi !!!

# %%
print("hello","Hi","!!!",sep="")
print("hello","Hi","!!!",sep="_*_")
# Out:
# helloHi!!!
# hello_*_Hi_*_!!!

# %%
print("hello Sam")
print("How are you")
# Out:
# hello Sam
# How are you

# %%
print("hello Sam\n",end="")
print("How are you")
# Out:
# hello Sam
# How are you

# %%
print("hello Sam",end="   ")
print("How are you")
# Out:
# hello Sam   How are you

# %%
print("hello Sam\n",end="     ")
print("How are you")
# Out:
# hello Sam
#      How are you

# %%
print("hello Sam",end="!!!! \n")
print("How are you")
# Out:
# hello Sam!!!!
# How are you

# %% [markdown]
# # Fundamental types in Python

# %%
a="Some text"
b=5
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# string
name1 = 'your "name"'
print(name1)
name2 = "He's coming to the party"
print(name2)
name3 = ''' XNews quotes : "He's coming to the party" '''
print(name3)
# Out:
# your "name"
# He's coming to the party
#  XNews quotes : "He's coming to the party"

# %%
print("hello \n\n hi") # NEXT LINE OR NEW LINE
# Out:
# hello
#
#  hi

# %%
var="hello"
print(len(var))  #  len(var)
# Out:
# 5

# %%
var="h e l l o"
print(len(var))  #  it also count space
# Out:
# 9

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
print(5+26)
# Out:
# 31

# %%
#Concatenation
'Hello '+'World'
# Out:
# 'Hello World'

# %%
'Day ' + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 'Day ' + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
'Day ' + "1"
# Out:
# 'Day 1'

# %%
"Day "+str(1)
# Out:
# 'Day 1'

# %%
#int(), #float, #bool()
print(type(1))

print(type(str(1)))
# Out:
# <class 'int'>
# <class 'str'>

# %%
abc="sam"
print(abc," anything ",abc," some text ",abc)
# Out:
# sam  anything  sam  some text  sam

# %%
string = "Hello, "
text = "World!"
modify = string + text
print(modify)
# Out:
# Hello, World!

# %% [markdown]
# # Simple Expressions

# %%
2>5  # > < ==   # Logical
# Out:
# False

# %%
5>4
# Out:
# True

# %%
......=.......
# Out:
#   Cell In[184], line 1
#     ......=.......
#        ^
# SyntaxError: invalid syntax

# %%
4==4
# Out:
# True

# %%
4>=4
# Out:
# True

# %%
24>=4
# Out:
# True

# %%
4<=4
# Out:
# True

# %%
4<=43
# Out:
# True

# %%
5>4 and 2>5
# Out:
# False

# %%
5>4 and 12>5
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True and False
# Out:
# False

# %%
2>3 or 9>4
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
# Addition and subtraction
print(5 + 5)
print(5 - 5)

# Multiplication and division
print(3 * 5)
print(10 / 2)

# Exponentiation
print(4 ** 2)

# Modulo
print(18 % 7)

#floor div
print("floor")
print(18/7)

print("floor=",18//7)

# How much is your $100 worth after 7 years?
print(100 * 1.1 ** 7+(4*6))# PEMDAS
# Out:
# 10
# 0
# 15
# 5.0
# 16
# 4
# floor
# 2.5714285714285716
# floor= 2
# 218.87171000000012

# %%
100 * 1.1 ** 7+(4*6)
# Out:
# 218.87171000000012

# %% [markdown]
# # Format

# %%
a="Sam"
b="Qwert"
print("Hi my name is",a,"I live in",b)
# Out:
# Hi my name is Sam I live in Qwert

# %%
print("Hi my name is {} I live in {}".format(a,b))
# Out:
# Hi my name is Sam I live in Qwert

# %%
c=100
print("Hi my name is {2} I live in {1} {2}".format(a,b,c))
# Out:
# Hi my name is 100 I live in Qwert 100

# %%
print(f"Hi my name is {a} I live in {b}")
# Out:
# Hi my name is Sam I live in Qwert

# %%
print(f"Hi my name is {a}, I live in {b}","hello",sep="***",end="")
# Out:
# Hi my name is 4, I live in 4***hello

# %%
print(f"Hi my name is {a}, I live in {b}","hello",sep="***",end=":")
# Out:
# Hi my name is 4, I live in 4***hello:

# %%
a = "Wing"
b = "London"
print(f"Hi my name is {a} I live in {b} ",100, "test", end="-endchar-", sep="-sepchar-")
# Out:
# Hi my name is Wing I live in London -sepchar-100-sepchar-test-endchar-

# %%
name = "Alice"
age = 30
greeting = f"Hello, my name is {name} and I am {age} years old."
print(greeting)
# Out:
# Hello, my name is Alice and I am 30 years old.

# %%
greeting_format = "Hello, my name is {} and I am {} years old.".format(name, age)
print(greeting_format)
# Out:
# Hello, my name is Alice and I am 30 years old.

# %% [markdown]
# # Input

# %%
input()
# Out:
# hi
# 'hi'

# %%
input("Name\n Plz= ")
# Out:
# Name
#  Plz= Sam
# 'Sam'

# %%
a=input()
a
# Out:
# Sameer
# 'Sameer'

# %%
type(a)
# Out:
# str

# %%
a=input()
# Out:
# 45

# %%
type(a)
# Out:
# str

# %%
type("123456")
# Out:
# str

# %%
type(12345)
# Out:
# int

# %% [markdown]
# * Input is by default STR

# %%
# que 
# Add 2 value 
a=input("a= ")
b=input("b= ")
print("the a+b result is ",a+b)
# Out:
# a= 4
# b= 5
# the a+b result is  45

# %%
# que 
# Add 2 value 
a=input("a= ")
b=input("b= ")
print("the a+b result is ",a+b)
# Out:
# a= Hello
# b= Sam
# the a+b result is  HelloSam

# %%
"hello"+" "+"SAM"
# Out:
# 'hello SAM'

# %%
v=int("3")
type(v)
# Out:
# int

# %% [markdown]
# * Resolving issue of int

# %%
a=input("a= ")
b=input("b= ")
a=int(a)
b=int(b)
print("the a+b result is ",a+b)
# Out:
# a= 4
# b= 5
# the a+b result is  9

# %%
int("abc") # Only a number can be a input
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[223], line 1
# ----> 1 int("abc") # Only a number can be a input
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
a=int(input("a= "))
b=int(input("b= "))

print("the a+b result is",a+b)
# Out:
# a= hi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[224], line 1
# ----> 1 a=int(input("a= "))
#       2 b=int(input("b= "))
#       4 print("the a+b result is",a+b)
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %% [markdown]
# # Some Good To Know Points

# %%
a,b,c=2,3,4
print(a,b,c)
# Out:
# 2 3 4

# %%
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 2 3
# 3 2

# %%
a=b=c=4

# %%
print(a,b,c)
# Out:
# 4 4 4

# %% [markdown]
# https://www.python.org/

# %% [markdown]
# ### QUE
# #### input -- name age and exp
# print statement by f format
#
# hello my name is NAME my age is AGE and my experience is EXP
